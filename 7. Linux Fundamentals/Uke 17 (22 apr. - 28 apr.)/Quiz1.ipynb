# %% [markdown]
# # **Quiz Linux (Mandag)** 🎉
# #### **1. Hvem var hovedarkitekten bak GNU-prosjektet på 1980-tallet?**
# * Richard Stallman.
#
# #### **2. En Kernel er:**
# * Den delen av OSet med høyest rettigheter.
#
# #### **3. Hva har du ikke lov å gjøre med et program med GNU - General Public License?**
# * Det du **ikke** kan gjøre er å hindre andre i å bruke programmet.
# * Det du kan for eksempel gjøre er å ta penger for programmet, gjøre endringer i koden eller spre kopier av programmet.
#
# #### **4. Når ble Linux-kjernen først publisert?**
# * Første Linux kjernen ble publisert i **1991**
#
# #### **5. Hvilken av disse er IKKE en standard toppnivåmappe i LINUX?**
# * bin ❌
# * tmp ❌
# * debug ✅
# * var ❌
#
# #### **6. standard bash-oppsett: Hvilke av disse kommandoene fører deg IKKE til din hjemmemappe?**
# * cd ❌
# * cd /home ✅
# * cd ~ ❌
# * cd $HOME ❌
#
# Kommandoene cd ~ og cd $HOME vil definitivt ta deg til din personlige hjemmemappe. Kommandoen cd uten noen argumenter vil også ta deg til din hjemmemappe, da det er standard oppførsel for denne kommandoen i Bash.
#
# Kommandoen cd /home tar deg til mappen /home, som vanligvis inneholder alle brukerens hjemmemapper på et Linux-system, men det er ikke den personlige hjemmemappen til den innloggede brukeren. Så, svaret på spørsmålet om hvilken kommando som ikke fører deg til din personlige hjemmemappe, er cd /home.
#
# #### **7. Hvilken kommando brukes for å skrive ut innholdet av en fil på skjermen?**
# * Svaret er **cat**
#
# #### **8. I hvilken fil lagres det informasjon om brukere?**
# I det siste skjermbildet ditt vises et spørsmål om hvor informasjon om brukere lagres i et Linux-system. Svaret som er merket riktig er `/etc/passwd`.
#
# Filen `/etc/passwd` inneholder grunnleggende informasjon om alle brukerkontoene på systemet. Denne filen inkluderer hver brukers brukernavn, bruker-ID (UID), gruppe-ID (GID), hjemmekatalog, kommando-tolk (shell), og noen ganger en beskrivelse av kontoen. Dette er en av de grunnleggende filene i et Unix-lignende system og brukes for brukeradministrasjon.
#
# De andre alternativene som er nevnt i spørsmålet ditt (`/home/users`, `/sys/fs`, `/usr/bin`) har ikke samme funksjon:
#
# - `/home/users` kunne teoretisk inneholde hjemmekatalogene for brukere, men den standard plasseringen for brukerkataloger er vanligvis bare `/home` fulgt av brukernavnet.
# - `/sys/fs` er del av sysfs (et filsystem brukt av Linux-kjernen for å eksponere informasjon om ulike kjerneresurser og maskinvareenheter til brukerrommet).
# - `/usr/bin` inneholder kjørbare filer for brukernivåprogrammer og er ikke relatert til lagring av brukerinformasjon.
#
# Derfor er `/etc/passwd` det riktige svaret for hvor brukerinformasjon lagres i et Linux-system.
#
# #### **9. Hvilken kommando brukes for å endre hvem som har eierskap til en fil?**
# * Svaret er **chown**
#
# #### **10. Hvem kan lese fila "dokument"?**
# [READ](quiz.png)
#
# I bildet ditt vises filrettighetene for en fil kalt "dokument" i Linux. Filrettighetene vises som `-rw-rw-r--`. Her er hva hver del betyr:
#
# - `-`: Dette er en vanlig fil.
# - `rw-`: Eieren av filen har lese- og skriverettigheter.
# - `rw-`: Gruppen tilknyttet filen har også lese- og skriverettigheter.
# - `r--`: Andre brukere (de som ikke er eieren eller i gruppen) har kun leserettigheter.
#
# Fra denne informasjonen kan vi konkludere med at:
# - Eieren av filen, som er "frank" (ut fra eierinformasjonen vist i oppføringene over), kan lese og skrive filen.
# - Medlemmer av gruppen "admins", som filen tilhører, kan også lese og skrive filen.
# - Alle andre brukere kan kun lese filen.
#
# Dermed kan alle brukere på systemet lese filen "dokument", men kun eieren og medlemmer av gruppen "admins" kan modifisere den.
#
# #### **11. Hva slags filtype ligger i /etc?**
# * Tekstfiler.
#
# #### **12.Hva gjør denne kommandoen? :vi /hallo /etc**
# * Lager fil som heter /hallo i /etc, hvis det ikke ligger fil som heter hallo.
#
# #### **13. Linux er en fork av UNIX**
# * False ❌
#
# #### **14. Hva ligger i /root**
# * Private filer til root bruker.
#
# #### **15. En package manager laster ned pakker, men du må så manuelt instalere dem**
# * False
#
# **Forklaring**
#
# Nei, det er ikke korrekt. En package manager i et Linux-basert operativsystem gjør generelt mer enn bare å laste ned pakker; den håndterer også installasjonen av disse pakkene automatisk. Denne prosessen inkluderer å løse avhengigheter mellom forskjellige programvarepakker, installere nødvendige biblioteker, og konfigurere programvaren på systemet.
#
# Når du bruker en kommando som apt install på et Debian-basert system, eller yum install på et Red Hat-basert system, vil package manageren finne pakken du ønsker, laste den ned og deretter utføre installasjonen av denne pakken uten at brukeren må gjøre noe mer. Dette inkluderer også nødvendige oppdateringer eller oppgraderinger av pakker som allerede er installert.
